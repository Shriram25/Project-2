# %%
import pymongo 
import pandas as pd

from pymongo import MongoClient

# %%
df2010 = pd.read_csv("data/Fortune500-2010.csv")
df2010['Year'] = 2010
df2010.columns
df2010
# Out:
#      rank                 company  revenue ($ millions) profit ($ millions)  \
# 0       1         Wal-Mart Stores              408214.0             14335.0
# 1       2             Exxon Mobil              284650.0             19280.0
# 2       3                 Chevron              163527.0             10483.0
# 3       4        General Electric              156779.0             11025.0
# 4       5   Bank of America Corp.              150450.0              6276.0
# ..    ...                     ...                   ...                 ...
# 495   496        Wisconsin Energy                4193.2               382.4
# 496   497    Northern Trust Corp.                4193.1               864.2
# 497   498     MDU Resources Group                4176.5              -123.3
# 498   499  CB Richard Ellis Group                4165.8                33.3
# 499   500             Blockbuster                4161.8              -558.2
#
#      Year
# 0    2010
# 1    2010
# 2    2010
# ...

# %%
df2011 = pd.read_csv("data/Fortune500-2011.csv")
df2011['Year'] = 2011
df2011.columns
df2011
# Out:
#      rank          company  revenue ($ millions) profit ($ millions)  Year
# 0       1  Wal-Mart Stores              421849.0             16389.0  2011
# 1       2      Exxon Mobil              354674.0             30460.0  2011
# 2       3          Chevron              196337.0             19024.0  2011
# 3       4   ConocoPhillips              184966.0             11358.0  2011
# 4       5       Fannie Mae              153825.0            -14014.0  2011
# ..    ...              ...                   ...                 ...   ...
# 495   496     Levi Strauss                4410.6               156.5  2011
# 496   497    NuStar Energy                4403.1               239.0  2011
# 497   498          Ruddick                4400.5               112.0  2011
# 498   499      D.R. Horton                4400.2               245.1  2011
# 499   500         Seaboard                4385.7               283.6  2011
#
# [500 rows x 5 columns]

# %%
df2012 = pd.read_csv("data/Fortune500-2012.csv")
df2012 ['Year'] = 2012
df2012.columns
df2012
# Out:
#      rank               company  revenue ($ millions)  profit ($ millions)  \
# 0       1           Exxon Mobil              452926.0              41060.0
# 1       2       Wal-Mart Stores              446950.0              15699.0
# 2       3               Chevron              245621.0              26895.0
# 3       4        ConocoPhillips              237272.0              12436.0
# 4       5        General Motors              150276.0               9190.0
# ..    ...                   ...                   ...                  ...
# 495   496      Rockwell Collins                4825.0                634.0
# 496   497  Erie Insurance Group                4824.0                169.0
# 497   498            Nash-Finch                4807.2                 35.8
# 498   499               KeyCorp                4780.0                920.0
# 499   500     Molina Healthcare                4769.9                 20.8
#
#      Year
# 0    2012
# 1    2012
# 2    2012
# 3    2012
# ...

# %%
df2013 = pd.read_csv("data/Fortune500-2013.csv")
df2013 ['Year'] = 2013
df2013.columns
df2013
# Out:
#      rank                     company  revenue ($ millions)  \
# 0       1             Wal-Mart Stores              469162.0
# 1       2                 Exxon Mobil              449886.0
# 2       3                     Chevron              233899.0
# 3       4                 Phillips 66              169551.0
# 4       5          Berkshire Hathaway              162463.0
# ..    ...                         ...                   ...
# 495   496  Old Republic International                4970.1
# 496   497        Simon Property Group                4880.1
# 497   498               YRC Worldwide                4850.5
# 498   499                          CA                4829.0
# 499   500                  Nash-Finch                4820.8
#
#      profit ($ millions)  Year
# 0                16999.0  2013
# 1                44880.0  2013
# 2                26179.0  2013
# 3                 4124.0  2013
# 4                14824.0  2013
# ..                   ...   ...
# ...

# %%
df2014 = pd.read_csv("data/Fortune500-2014.csv")
df2014 ['Year'] = 2014
df2014.columns
df2014
# Out:
#      rank                   company  revenue ($ millions)  \
# 0       1           Wal-Mart Stores              476294.0
# 1       2               Exxon Mobil              407666.0
# 2       3                   Chevron              220356.0
# 3       4        Berkshire Hathaway              182150.0
# 4       5                     Apple              170910.0
# ..    ...                       ...                   ...
# 495   496                 Lorillard                4972.0
# 496   497                 Alleghany                4972.0
# 497   498                    Airgas                4958.0
# 498   499  First American Financial                4956.0
# 499   500            United Rentals                4955.0
#
#      profit ($ millions)  Year
# 0                16022.0  2014
# 1                32580.0  2014
# 2                21423.0  2014
# 3                19476.0  2014
# 4                37037.0  2014
# ..                   ...   ...
# 495               1180.0  2014
# ...

# %%
df2015 = pd.read_csv("data/Fortune500-2015.csv")
df2015 ['Year'] = 2015
df2015.columns
df2015
# Out:
#      rank                    company  revenue ($ millions)  \
# 0       1                    Walmart                485651
# 1       2                Exxon Mobil                382597
# 2       3                    Chevron                203784
# 3       4         Berkshire Hathaway                194673
# 4       5                      Apple                182795
# ..    ...                        ...                   ...
# 495   496  Pioneer Natural Resources                  5293
# 496   497          Wyndham Worldwide                  5281
# 497   498              Owens Corning                  5276
# 498   499                  Alleghany                  5232
# 499   500      McGraw Hill Financial                  5190
#
#      profit ($ millions)  Year
# 0                  16363  2015
# 1                  32520  2015
# 2                  19241  2015
# 3                  19872  2015
# 4                  39510  2015
# ..                   ...   ...
# ...

# %%
df2016 = pd.read_csv("data/Fortune500-2016.csv")
df2016 ['Year'] = 2016
df2016.columns
df2016
# Out:
#      rank                   company  revenue ($ millions)  \
# 0       1                   Walmart                482130
# 1       2               Exxon Mobil                246204
# 2       3                     Apple                233715
# 3       4        Berkshire Hathaway                210821
# 4       5                  McKesson                181241
# ..    ...                       ...                   ...
# 495   496  Telephone & Data Systems                  5176
# 496   497  First American Financial                  5176
# 497   498                       NVR                  5170
# 498   499      Cincinnati Financial                  5142
# 499   500         Burlington Stores                  5130
#
#      profit ($ millions)  Year
# 0                  14694  2016
# 1                  16150  2016
# 2                  53394  2016
# 3                  24083  2016
# 4                   1476  2016
# ..                   ...   ...
# 495                  219  2016
# ...

# %%
df2017 = pd.read_csv("data/Fortune500-2017.csv")
df2017 ['Year'] = 2017
df2017.columns
df2017
# Out:
#      rank             company  revenue ($ millions)  profit ($ millions)  Year
# 0       1             Walmart                485873              13643.0  2017
# 1       2  Berkshire Hathaway                223604              24074.0  2017
# 2       3               Apple                215639              45687.0  2017
# 3       4         Exxon Mobil                205004               7840.0  2017
# 4       5            McKesson                192487               2258.0  2017
# ..    ...                 ...                   ...                  ...   ...
# 495   496       Michaels Cos.                  5197                378.2  2017
# 496   497       Toll Brothers                  5170                382.1  2017
# 497   498               Yahoo                  5169               -214.3  2017
# 498   499       Vistra Energy                  5164                  NaN  2017
# 499   500      ABM Industries                  5145                 57.2  2017
#
# [500 rows x 5 columns]

# %%
df2018 = pd.read_csv("data/Fortune500-2018.csv")
df2018 ['Year'] = 2018
df2018.columns
df2018
# Out:
#      rank                    company  revenue ($ millions)  \
# 0       1                    Walmart              500343.0
# 1       2                Exxon Mobil              244363.0
# 2       3         Berkshire Hathaway              242137.0
# 3       4                      Apple              229234.0
# 4       5         UnitedHealth Group              201159.0
# ..    ...                        ...                   ...
# 495   496         Polaris Industries                5504.8
# 496   497  Pioneer Natural Resources                5455.0
# 497   498             ABM Industries                5453.6
# 498   499              Vistra Energy                5430.0
# 499   500                     Cintas                5428.9
#
#      profit ($ millions)  Year
# 0                 9862.0  2018
# 1                19710.0  2018
# 2                44940.0  2018
# 3                48351.0  2018
# 4                10558.0  2018
# ..                   ...   ...
# ...

# %%
df2019 = pd.read_csv("data/Fortune500-2019.csv")
df2019 ['Year'] = 2019
df2019.columns
df2019
# Out:
#      rank               company  revenue ($ millions)  profit ($ millions)  \
# 0       1               Walmart              514405.0               6670.0
# 1       2           Exxon Mobil              290212.0              20840.0
# 2       3                 Apple              265595.0              59531.0
# 3       4    Berkshire Hathaway              247837.0               4021.0
# 4       5            Amazon.com              232887.0              10073.0
# ..    ...                   ...                   ...                  ...
# 495   496  Simon Property Group                5657.9               2440.1
# 496   497               Navient                5610.0                395.0
# 497   498         Western Union                5589.9                851.9
# 498   499        Peabody Energy                5581.8                646.9
# 499   500          Levi Strauss                5575.4                283.1
#
#      Year
# 0    2019
# 1    2019
# 2    2019
# 3    2019
# ...

# %%
df2010_2019 = pd.concat([df2010,df2011,df2012,df2013,df2014,df2015,df2016,df2017,df2018,df2019])

# %%
df2010_2019.reset_index()
# Out:
#       index  rank                company  revenue ($ millions)  \
# 0         0     1        Wal-Mart Stores              408214.0
# 1         1     2            Exxon Mobil              284650.0
# 2         2     3                Chevron              163527.0
# 3         3     4       General Electric              156779.0
# 4         4     5  Bank of America Corp.              150450.0
# ...     ...   ...                    ...                   ...
# 4995    495   496   Simon Property Group                5657.9
# 4996    496   497                Navient                5610.0
# 4997    497   498          Western Union                5589.9
# 4998    498   499         Peabody Energy                5581.8
# 4999    499   500           Levi Strauss                5575.4
#
#      profit ($ millions)  Year
# 0                14335.0  2010
# 1                19280.0  2010
# 2                10483.0  2010
# 3                11025.0  2010
# 4                 6276.0  2010
# ...

# %%
df1000 = pd.read_csv("data/fortune1000.csv", encoding= 'unicode_escape')

# %%
df1000
# Out:
#      rank                            title Previous Rank Revenues ($M)  \
# 0       1                          Walmart             1     $500,343
# 1       2                      Exxon Mobil             4     $244,363
# 2       3               Berkshire Hathaway             2     $242,137
# 3       4                            Apple             3     $229,234
# 4       5               UnitedHealth Group             6     $201,159
# ..    ...                              ...           ...           ...
# 995   996         SiteOne Landscape Supply           NaN       $1,862
# 996   997  Charles River Laboratories Intl           NaN       $1,858
# 997   998                        CoreLogic           952       $1,851
# 998   999                     Ensign Group           NaN       $1,849
# 999  1000                              HCP           798       $1,848
#
#     Revenue Change Profits ($M) Profit Change Assets ($M)  \
# 0            3.00%   $9,862.00        -27.70%   $204,522
# ...

# %%
expanded_df = pd.read_csv("data/f500.csv")

# %%
expanded_df_new = expanded_df[ ["Title","City","State","Latitude","Longitude","Industry" ]   ]

# %%
df1000_new = df1000[["title","City","State","Latitude","Longitude","Industry" ]]

# %%
df1000_new
# Out:
#                                title           City State   Latitude  \
# 0                            Walmart    Bentonville    AR  36.372854
# 1                        Exxon Mobil         Irving    TX  32.814018
# 2                 Berkshire Hathaway          Omaha    NE  41.256537
# 3                              Apple      Cupertino    CA  37.322998
# 4                 UnitedHealth Group     Minnetonka    MN  44.921184
# ..                               ...            ...   ...        ...
# 995         SiteOne Landscape Supply        Roswell    GA  34.023243
# 996  Charles River Laboratories Intl     Wilmington    MA  42.548171
# 997                        CoreLogic         Irvine    CA  33.684567
# 998                     Ensign Group  Mission Viejo    CA  33.596891
# 999                              HCP         Irvine    CA  33.684567
#
#       Longitude                                  Industry
# 0    -94.208817                     General Merchandisers
# ...

# %%
expanded_df_new
# Out:
#                          Title         City State   Latitude   Longitude  \
# 0                      Walmart  Bentonville    AR  36.372854  -94.208817
# 1                  Exxon Mobil       Irving    TX  32.814018  -96.948894
# 2           Berkshire Hathaway        Omaha    NE  41.256537  -95.934503
# 3                        Apple    Cupertino    CA  37.322998 -122.032182
# 4           UnitedHealth Group   Minnetonka    MN  44.921184  -93.468749
# ..                         ...          ...   ...        ...         ...
# 495         Polaris Industries       Medina    MN  45.035241  -93.582459
# 496  Pioneer Natural Resources       Irving    TX  32.814018  -96.948894
# 497             ABM Industries     New York    NY  40.712775  -74.005973
# 498              Vistra Energy       Irving    TX  32.814018  -96.948894
# 499                     Cintas   Cincinnati    OH  39.103118  -84.512020
#
#                                      Industry
# ...

# %%
df1000_new.rename(columns={"title":"company"},inplace=True)

# %%
#newdf = pd.merge(df,newdfall , how='left', on='company')

# %%
df2010_2019['company'].replace('Wal-Mart Stores', 'Walmart', inplace = True)

# %%
df1000_new
# Out:
#                              company           City State   Latitude  \
# 0                            Walmart    Bentonville    AR  36.372854
# 1                        Exxon Mobil         Irving    TX  32.814018
# 2                 Berkshire Hathaway          Omaha    NE  41.256537
# 3                              Apple      Cupertino    CA  37.322998
# 4                 UnitedHealth Group     Minnetonka    MN  44.921184
# ..                               ...            ...   ...        ...
# 995         SiteOne Landscape Supply        Roswell    GA  34.023243
# 996  Charles River Laboratories Intl     Wilmington    MA  42.548171
# 997                        CoreLogic         Irvine    CA  33.684567
# 998                     Ensign Group  Mission Viejo    CA  33.596891
# 999                              HCP         Irvine    CA  33.684567
#
#       Longitude                                  Industry
# 0    -94.208817                     General Merchandisers
# ...

# %%
expanded_df_new.rename(columns={"Title":"company"},inplace=True)

# %%
expanded_df_new
# Out:
#                        company         City State   Latitude   Longitude  \
# 0                      Walmart  Bentonville    AR  36.372854  -94.208817
# 1                  Exxon Mobil       Irving    TX  32.814018  -96.948894
# 2           Berkshire Hathaway        Omaha    NE  41.256537  -95.934503
# 3                        Apple    Cupertino    CA  37.322998 -122.032182
# 4           UnitedHealth Group   Minnetonka    MN  44.921184  -93.468749
# ..                         ...          ...   ...        ...         ...
# 495         Polaris Industries       Medina    MN  45.035241  -93.582459
# 496  Pioneer Natural Resources       Irving    TX  32.814018  -96.948894
# 497             ABM Industries     New York    NY  40.712775  -74.005973
# 498              Vistra Energy       Irving    TX  32.814018  -96.948894
# 499                     Cintas   Cincinnati    OH  39.103118  -84.512020
#
#                                      Industry
# ...

# %%
newdf2 = pd.merge(df2010_2019,df1000_new,how='left',on='company')

# %%
newdf2
# Out:
#       rank                company  revenue ($ millions) profit ($ millions)  \
# 0        1                Walmart              408214.0             14335.0
# 1        2            Exxon Mobil              284650.0             19280.0
# 2        3                Chevron              163527.0             10483.0
# 3        4       General Electric              156779.0             11025.0
# 4        5  Bank of America Corp.              150450.0              6276.0
# ...    ...                    ...                   ...                 ...
# 4995   496   Simon Property Group                5657.9              2440.1
# 4996   497                Navient                5610.0                 395
# 4997   498          Western Union                5589.9               851.9
# 4998   499         Peabody Energy                5581.8               646.9
# 4999   500           Levi Strauss                5575.4               283.1
#
#       Year          City State   Latitude   Longitude  \
# ...

# %%
newdf2.describe(include='all')
# Out:
#                rank           company  revenue ($ millions)  \
# count   5000.000000              5000           5000.000000
# unique          NaN               820                   NaN
# top             NaN  Procter & Gamble                   NaN
# freq            NaN                10                   NaN
# mean     250.498800               NaN          23936.188080
# std      144.351109               NaN          38961.529257
# min        1.000000               NaN           4161.800000
# 25%      125.750000               NaN           6956.800000
# 50%      250.500000               NaN          11118.000000
# 75%      375.250000               NaN          22814.100000
# max      500.000000               NaN         514405.000000
#
#         profit ($ millions)         Year      City State     Latitude  \
# count                4998.0  5000.000000      3985  3992  3992.000000
# unique               4195.0          NaN       249    39          NaN
# ...

# %%
newdf.loc[newdf.company == "CVS Caremark" ,'Longitude' ] = -71.5148
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-13ffea259bcf> in <module>
# ----> 1 newdf.loc[newdf.company == "CVS Caremark" ,'Longitude' ] = -71.5148
#
# NameError: name 'newdf' is not defined

# %%
newdf[newdf["company"] == "CVS Caremark"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-beb803216213> in <module>
# ----> 1 newdf[newdf["company"] == "CVS Caremark"]
#
# NameError: name 'newdf' is not defined

# %%
newdf2[newdf2['City'].isnull()]
# Out:
#       rank                             company  revenue ($ millions)  \
# 8        9             J.P. Morgan Chase & Co.              115632.0
# 9       10                     Hewlett-Packard              114552.0
# 12      13              Verizon Communications              107808.0
# 15      16        American International Group              103189.0
# 17      18                        CVS Caremark               98729.0
# ...    ...                                 ...                   ...
# 4920   421  Western & Southern Financial Group                7205.0
# 4957   458                           Dillard's                6503.3
# 4961   462                      M&T Bank Corp.                6454.7
# 4969   470                          S&P Global                6258.0
# 4973   474               L3Harris Technologies                6182.0
#
#      profit ($ millions)  Year City State  Latitude  Longitude Industry
# ...

# %%
newdf2[newdf2['company']=="Safeway"]
# Out:
#       rank  company  revenue ($ millions) profit ($ millions)  Year City  \
# 51      52  Safeway               40850.7             -1097.5  2010  NaN
# 559     60  Safeway               41050.0               589.8  2011  NaN
# 1062    63  Safeway               43630.2               516.7  2012  NaN
# 1561    62  Safeway               44206.5               596.5  2013  NaN
# 2066    67  Safeway               42982.0                3508  2014  NaN
# 2583    84  Safeway               36643.0                 113  2015  NaN
#
#      State  Latitude  Longitude Industry
# 51     NaN       NaN        NaN      NaN
# 559    NaN       NaN        NaN      NaN
# 1062   NaN       NaN        NaN      NaN
# 1561   NaN       NaN        NaN      NaN
# 2066   NaN       NaN        NaN      NaN
# 2583   NaN       NaN        NaN      NaN

# %%
newdf2.loc[newdf2.company == "Safeway" ,'Industry'] = "Retail"

# %%
newdf2.loc[newdf2.company == "Safeway" ,'State'] = "CA"

# %%
newdf2.loc[newdf2.company == "Safeway" ,'City'] = "Pleasanton"

# %%
newdf2.to_csv("newdf2.csv")

# %%
newdf2
# Out:
#       rank                company   revenue profit ($ millions)  Year  \
# 0        1                Walmart  408214.0             14335.0  2010
# 1        2            Exxon Mobil  284650.0             19280.0  2010
# 2        3                Chevron  163527.0             10483.0  2010
# 3        4       General Electric  156779.0             11025.0  2010
# 4        5  Bank of America Corp.  150450.0              6276.0  2010
# ...    ...                    ...       ...                 ...   ...
# 4995   496   Simon Property Group    5657.9              2440.1  2019
# 4996   497                Navient    5610.0                 395  2019
# 4997   498          Western Union    5589.9               851.9  2019
# 4998   499         Peabody Energy    5581.8               646.9  2019
# 4999   500           Levi Strauss    5575.4               283.1  2019
#
#               City State   Latitude   Longitude                      Industry
# ...

# %%
newdf2.rename(columns = {'profit ($ millions' : 'profit'} , inplace = True)

# %%
newdf2.to_csv("newdf2.csv")
